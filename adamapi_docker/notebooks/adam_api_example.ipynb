# %% [markdown]
# # Adam API usage example
# https://docs.neanias.eu/projects/c2-dataexploration/en/latest/

# %%
import os
import adamapi
from adamapi import Auth

# %%
a = Auth()
a.setKey(os.environ["ADAM_API_KEY"])
a.setAdamCore("https://explorer-space.adamplatform.eu")
a.authorize()

# %%
auth_data
# Out:
# {'expires_at': '2022-05-11T10:50:04.974Z',
#  'access_token': '97cd7f9435044dbf8177801c3ddefce5',
#  'refresh_token': '1dec0dee4e6d41eba9f602e42407340d',
#  'expires_in': 3600}

# %%
from adamapi import Datasets
datasets = Datasets(a)
items = datasets.getDatasets()
print( "Available datasets:")
for key in items: 
    print( key )
# Out:
# Available datasets:
# type
# properties
# 58592:MRO_CTX

# %%
datasetId = "58592:MRO_CTX"

# %%
metadata = datasets.getDatasets(datasetId)
metadata
# Out:
# {'datasetId': 'MRO_CTX',
#  'creationDate': '2021-04-13T15:23:24Z',
#  'dataType': 'Float32',
#  'epsg': '4326',
#  'keywords': [],
#  'license': {'documentationUrl': '',
#   'dataProviderName': 'Jacobs University',
#   'dataProviderUrl': '',
#   'licenseId': '',
#   'dataPolicy': '',
#   'doi': '',
#   'credits': ''},
#  'maxDate': '2020-08-31T18:19:37Z',
#  'maxValue': [0.2],
#  'minDate': '2006-03-24T04:41:07Z',
#  'minValue': [-0.02],
#  'noDataValue': -9999,
#  'numberOfRecords': 7495,
#  'profile': {'profileSchema': 'space_profile.json',
#   'name': 'Space',
#   'targetName': 'MARS',
#   'observationMode': 'EDR',
#   'instrument': 'CONTEXT CAMERA',
#   'instrumentId': 'CTX',
#   'mission': 'MARS RECONNAISSANCE ORBITER',
#   'missionId': 'MRO',
#   'processingLevel': '',
#   'solarLongitudeMin': '',
#   'solarLongitudeMax': '',
#   'solarDistanceMin': '',
#   'solarDistanceMax': '',
#   'solarLongitudeStart': '',
#   'solarLongitudeEnd': '',
#   'EmissionAngleMax': 32.39,
#   'EmissionAngleMin': 0.03,
#   'IncidenceAngleMax': 86.83,
#   'IncidenceAngleMin': 32.49,
#   'PhaseAngleMax': 95.09,
#   'PhaseAngleMin': 13.16,
#   'MapScaleMax': 12.27,
#   'MapScaleMin': 4.97,
#   'ObservationTimeMax': '2020-08-19T14:21:29.094',
#   'ObservationTimeMin': '2006-11-08T06:33:07.784'},
#  'resolutionUnit': 'metre',
#  'scaleFactor': 1,
#  'temporalResolution': 'Irregular',
#  'unit': '',
#  'unitDescription': '',
#  'updateDate': '2022-05-10T10:42:22Z',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-179.9564906, -89.6981043],
#     [179.9880362, -89.6981043],
#     [179.9880362, 89.7832671],
#     [-179.9564906, 89.7832671],
#     [-179.9564906, -89.6981043]]]},
#  'resolutions': [6.0, 38.0, 5.0, 7.0, 9.0],
#  'anyText': 'MARS-proj,ESA,PT2M,ESA',
#  'applications': ['Planetary'],
#  'datasetManagerOrganisation': 'MEEO',
#  'description': 'Products from Context Camera instrument in Mars Reconnaissance Orbiter',
#  'title': 'Mars Reconnaissance Orbiter - Context Camera',
#  'nodataValue': -9999,
#  'timeReferenceSystem': 'UTC',
#  'units': 'm',
#  'unitsDescription': 'N/A',
#  'colorTable': 'grayscale',
#  'ingestionInfo': '',
#  'legend': [],
#  'pathToOriginalData': '',
#  'project': [],
#  'services': ['MWCS', 'ADAM', 'AdamApi'],
#  'pricing': {'nativeSource': {'name': 'nfs', 'cost': 0, 'pricingPolicy': ''}},
#  'filtersEnabled': {'type': 'object',
#   'title': 'Dataset filters',
#   'properties': {'startDate': {'title': 'Start Date',
#     'type': 'string',
#     'format': 'date',
#     'text_rule': 'false',
#     'ops_only': 'false',
#     'math_rule': 'false',
#     'order_rule': 'false',
#     'pattern': '^d{4}-[01]d-[0-3]d(T[0-2]d:[0-9]d:[0-9]dZ)?$'},
#    'endDate': {'title': 'End Date',
#     'type': 'string',
#     'format': 'date',
#     'ops_only': 'false',
#     'text_rule': 'false',
#     'math_rule': 'false',
#     'order_rule': 'false',
#     'pattern': '^d{4}-[01]d-[0-3]d(T[0-2]d:[0-9]d:[0-9]dZ)?$'},
#    'targetName': {'title': 'Target Name',
#     'type': 'string',
#     'format': 'string',
#     'text_rule': 'true',
#     'math_rule': 'false',
#     'order_rule': 'false',
#     'ops_only': 'false',
#     'locked': 'true',
#     'default': 'MARS'},
#    'PhaseAngle': {'title': 'Phase Angle Filter',
#     'type': 'number',
#     'format': 'string',
#     'text_rule': 'false',
#     'math_rule': 'true',
#     'order_rule': 'false',
#     'ops_only': 'false',
#     'locked': 'true'},
#    'EmissionAngle': {'title': 'Emission Angle Filter',
#     'type': 'number',
#     'format': 'string',
#     'text_rule': 'false',
#     'math_rule': 'true',
#     'order_rule': 'false',
#     'ops_only': 'false',
#     'locked': 'true'},
#    'IncidenceAngle': {'title': 'Incidence Angle Filter',
#     'type': 'number',
#     'format': 'string',
#     'text_rule': 'false',
#     'math_rule': 'true',
#     'order_rule': 'false',
#     'ops_only': 'false',
#     'locked': 'true'},
#    'MapScale': {'title': 'Map Scale Filter',
#     'type': 'number',
#     'format': 'string',
#     'text_rule': 'false',
#     'math_rule': 'true',
#     'order_rule': 'false',
#     'ops_only': 'false',
#     'locked': 'true'},
#    'productId': {'title': 'Product Identifier',
#     'type': 'string',
#     'format': 'string',
#     'text_rule': 'true',
#     'math_rule': 'false',
#     'order_rule': 'true',
#     'ops_only': 'false',
#     'locked': 'true'},
#    'observationMode': {'title': 'Observation Mode',
#     'type': 'string',
#     'format': 'select',
#     'text_rule': 'true',
#     'math_rule': 'false',
#     'order_rule': 'true',
#     'ops_only': 'false',
#     'locked': 'true',
#     'enum': ['', 'EDR', 'RDR'],
#     'default': ''}}},
#  'previews': ''}

# %%
print(f"Number of images: {metadata['numberOfRecords']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 print(f"Number of images: {metadata['numberOfRecords']}")
#
# NameError: name 'metadata' is not defined

# %% [markdown]
# ## Count all products

# %%
min_start_date = '2006-03-24'
max_end_date = '2020-08-30'

# %%
from adamapi import Search

# %%
def downloadMetadata(auth, start_date, end_date):
    search = Search(auth)
    maxRec = 200
    search_result = search.getProducts(
        datasetId,
        maxRecords=maxRec,
        startIndex=0,
        outputAttributes=['productId'],
        startDate=start_date,
        endDate=end_date
    )
    print(f"Total products: {len(search_result['content'])}")
    return search_result["content"]
#for product in search_result["content"][0:10]:
#    print(product["productId"])

# %%
files_metadata = []

# %%
from dateutil.relativedelta import relativedelta
start_date = date(2015, 7, 1)
end_date = date(2016, 1, 1)
while start_date < end_date:
    next_date = start_date + relativedelta(days=1)
    print(f"Download data from {start_date} - {next_date}")    
    files_metadata = files_metadata + downloadMetadata(a, start_date, next_date)
    start_date = next_date
# Out:
# Download data from 2015-07-01 - 2015-07-02
# Total products: 0
# Download data from 2015-07-02 - 2015-07-03
# Total products: 0
# Download data from 2015-07-03 - 2015-07-04
# Total products: 0
# Download data from 2015-07-04 - 2015-07-05
# Total products: 0
# Download data from 2015-07-05 - 2015-07-06
# Total products: 0
# Download data from 2015-07-06 - 2015-07-07
# Total products: 0
# Download data from 2015-07-07 - 2015-07-08
# Total products: 0
# Download data from 2015-07-08 - 2015-07-09
# Total products: 1
# Download data from 2015-07-09 - 2015-07-10
# Total products: 3
# Download data from 2015-07-10 - 2015-07-11
# Total products: 2
# Download data from 2015-07-11 - 2015-07-12
# Total products: 0
# Download data from 2015-07-12 - 2015-07-13
# Total products: 0
# Download data from 2015-07-13 - 2015-07-14
# Total products: 0
# Download data from 2015-07-14 - 2015-07-15
# Total products: 1
# Download data from 2015-07-15 - 2015-07-16
# Total products: 2
# Download data from 2015-07-16 - 2015-07-17
# Total products: 10
# Download data from 2015-07-17 - 2015-07-18
# Total products: 22
# Download data from 2015-07-18 - 2015-07-19
# Total products: 31
# Download data from 2015-07-19 - 2015-07-20
# Total products: 33
# Download data from 2015-07-20 - 2015-07-21
# Total products: 33
# Download data from 2015-07-21 - 2015-07-22
# Total products: 35
# Download data from 2015-07-22 - 2015-07-23
# Total products: 31
# Download data from 2015-07-23 - 2015-07-24
# Total products: 27
# Download data from 2015-07-24 - 2015-07-25
# Total products: 30
# Download data from 2015-07-25 - 2015-07-26
# Total products: 31
# Download data from 2015-07-26 - 2015-07-27
# Total products: 17
# Download data from 2015-07-27 - 2015-07-28
# Total products: 3
# Download data from 2015-07-28 - 2015-07-29
# Total products: 0
# Download data from 2015-07-29 - 2015-07-30
# Total products: 0
# Download data from 2015-07-30 - 2015-07-31
# Total products: 0
# Download data from 2015-07-31 - 2015-08-01
# Total products: 6
# Download data from 2015-08-01 - 2015-08-02
# Total products: 20
# Download data from 2015-08-02 - 2015-08-03
# Total products: 31
# Download data from 2015-08-03 - 2015-08-04
# Total products: 39
# Download data from 2015-08-04 - 2015-08-05
# Total products: 35
# Download data from 2015-08-05 - 2015-08-06
# Total products: 29
# Download data from 2015-08-06 - 2015-08-07
# Total products: 28
# Download data from 2015-08-07 - 2015-08-08
# Total products: 23
# Download data from 2015-08-08 - 2015-08-09
# Total products: 28
# Download data from 2015-08-09 - 2015-08-10
# Total products: 30
# Download data from 2015-08-10 - 2015-08-11
# Total products: 33
# Download data from 2015-11-20 - 2015-11-21
# Total products: 38
# Download data from 2015-11-21 - 2015-11-22
# Total products: 43
# Download data from 2015-11-22 - 2015-11-23
# Total products: 40
# Download data from 2015-11-23 - 2015-11-24
# Total products: 37
# Download data from 2015-11-24 - 2015-11-25
# Total products: 41
# Download data from 2015-11-25 - 2015-11-26
# Total products: 39
# Download data from 2015-11-26 - 2015-11-27
# Total products: 34
# Download data from 2015-11-27 - 2015-11-28
# Total products: 41
# Download data from 2015-11-28 - 2015-11-29
# Total products: 40
# Download data from 2015-11-29 - 2015-11-30
# Total products: 27
# Download data from 2015-11-30 - 2015-12-01
# Total products: 23
# Download data from 2015-12-01 - 2015-12-02
# Total products: 37
# Download data from 2015-12-02 - 2015-12-03
# Total products: 47
# Download data from 2015-12-03 - 2015-12-04
# Total products: 39
# Download data from 2015-12-04 - 2015-12-05
# Total products: 31
# Download data from 2015-12-05 - 2015-12-06
# Total products: 30
# Download data from 2015-12-06 - 2015-12-07
# Total products: 32
# Download data from 2015-12-07 - 2015-12-08
# Total products: 28
# Download data from 2015-12-08 - 2015-12-09
# Total products: 29
# Download data from 2015-12-09 - 2015-12-10
# Total products: 34
# Download data from 2015-12-10 - 2015-12-11
# Total products: 26
# Download data from 2015-12-11 - 2015-12-12
# Total products: 24
# Download data from 2015-12-12 - 2015-12-13
# Total products: 33
# Download data from 2015-12-13 - 2015-12-14
# Total products: 18
# Download data from 2015-12-14 - 2015-12-15
# Total products: 0
# Download data from 2015-12-15 - 2015-12-16
# Total products: 0
# Download data from 2015-12-16 - 2015-12-17
# Total products: 0
# Download data from 2015-12-17 - 2015-12-18
# Total products: 1
# Download data from 2015-12-18 - 2015-12-19
# Total products: 1
# Download data from 2015-12-19 - 2015-12-20
# Total products: 0
# Download data from 2015-12-20 - 2015-12-21
# Total products: 0
# Download data from 2015-12-21 - 2015-12-22
# Total products: 0
# Download data from 2015-12-22 - 2015-12-23
# Total products: 1
# Download data from 2015-12-23 - 2015-12-24
# Total products: 1
# Download data from 2015-12-24 - 2015-12-25
# Total products: 0
# Download data from 2015-12-25 - 2015-12-26
# Total products: 0
# Download data from 2015-12-26 - 2015-12-27
# Total products: 0
# Download data from 2015-12-27 - 2015-12-28
# Total products: 0
# Download data from 2015-12-28 - 2015-12-29
# Total products: 0
# Download data from 2015-12-29 - 2015-12-30
# Total products: 0
# Download data from 2015-12-30 - 2015-12-31
# Total products: 0
# Download data from 2015-12-31 - 2016-01-01
# Total products: 0

# %%
len(files_metadata)
# Out:
# 3636

# %%
! pwd
# Out:
# /app

# %%
import pickle
pickle.dump(files_metadata, open('/shared_dir/files_metadata.pickle', 'wb'))

# %%
first_product = search_result["content"][0]["productId"]
first_product
# Out:
# 'N09_066084_2025_XN_22N104W.tif'

# %%
from adamapi import GetData
data=GetData(a)
product = first_product
data.getData(datasetId, productId = product, outputFname=f"/shared_dir/{first_product}")
# Out:
# '/shared_dir/N09_066084_2025_XN_22N104W.tif'
